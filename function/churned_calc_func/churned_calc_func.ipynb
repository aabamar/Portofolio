# %% [markdown]
# # Churn User
#
# ---

# %% [markdown]
# **Function description**
#
# from a userID and its subscription status, this function use to determine the number of churned (unsubscribed user) on a specific month

# %% [markdown]
# **Case Example**
#
# **Input**
# ```python
# user_data_2022 = [
#     ['2062', 'February'],
#     ['5679', 'October'],
#     ['4690', 'September'],
#     ['8748', 'March'],
#     ['8318', 'December'],
#     ['7814', 'February'],
#     ['9850', 'November'],
#     ['2154', 'September'],
#     ['7767', 'October'],
#     ['3755', 'January'],
#     ['3117', 'March'],
#     ['4197', 'December'],
#     ['7276', 'December'],
#     ['3387', 'May'],
#     ['2160', 'November'],
#     ['9626', 'October'],
#     ['5430', 'July'],
#     ['7055', 'January'],
#     ['7838', 'July'],
#     ['8991', 'May'],
#     ['6238', 'September'],
#     ['8033', 'October'],
#     ['8711', 'January'],
#     ['9999', 'December'],
#     ['9980', 'May'],
#     ['8282', 'September'],
#     ['1508', 'March'],
#     ['9899', 'January'],
#     ['4745', 'October'],
#     ['9615', 'August'],
#     ['8526', 'July'],
#     ['8736', 'January'],
#     ['6244', 'December'],
#     ['8319', 'August'],
#     ['1415', 'April'],
#     ['3413', 'March'],
#     ['1683', 'January'],
#     ['8825', 'November'],
#     ['6098', 'August'],
#     ['2627', 'February']
# ]
# ```
# **Output**
# ```python
# 20
# ```

# %%
def calculate_churned(user_data, month):
  '''
  Function to determine the number of churned (unsubscribed user) on a specific month

  Parameters
  ----------
  user_data : list
    contains the userId and subscribe until ...
  month : string
    contains month to determine the churned user

  Returns
  --------
  churned : int
      contains the number of churned user before month
  '''

  churned = 0 # output variable

  # reference variable to convert month into int/number
  month_dict = {'January' : 1,
                'February' : 2,
                'March' : 3,
                'April' : 4,
                'May': 5,
                'June': 6,
                'July': 7,
                'August': 8,
                'September':9,
                'October': 10,
                'November': 11,
                'December': 12
                }
  num_month = month_dict[month] # convert month variable into int with reference variable

  # code for calculate churned user in user_data
  for username, subscribe in user_data:
    num_subscribe = month_dict[subscribe] # convert user subscribe variable from user_data into int with reference variable

    if num_subscribe < num_month:
      churned += 1

  return churned # return churned variable

# %%
user_data_2022 = [
    ['2062', 'February'],
    ['5679', 'October'],
    ['4690', 'September'],
    ['8748', 'March'],
    ['8318', 'December'],
    ['7814', 'February'],
    ['9850', 'November'],
    ['2154', 'September'],
    ['7767', 'October'],
    ['3755', 'January'],
    ['3117', 'March'],
    ['4197', 'December'],
    ['7276', 'December'],
    ['3387', 'May'],
    ['2160', 'November'],
    ['9626', 'October'],
    ['5430', 'July'],
    ['7055', 'January'],
    ['7838', 'July'],
    ['8991', 'May'],
    ['6238', 'September'],
    ['8033', 'October'],
    ['8711', 'January'],
    ['9999', 'December'],
    ['9980', 'May'],
    ['8282', 'September'],
    ['1508', 'March'],
    ['9899', 'January'],
    ['4745', 'October'],
    ['9615', 'August'],
    ['8526', 'July'],
    ['8736', 'January'],
    ['6244', 'December'],
    ['8319', 'August'],
    ['1415', 'April'],
    ['3413', 'March'],
    ['1683', 'January'],
    ['8825', 'November'],
    ['6098', 'August'],
    ['2627', 'February']
]

res = calculate_churned(user_data = user_data_2022,
                        month = 'August')
print(res)
# Out:
# 20
